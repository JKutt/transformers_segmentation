# %% [markdown]
# # Airborne MT forward modelling and inversion notebook V0.1
#
# Note: this notebook can be modified to do qamt or controlled source. TODO

# %%
# import SimPEG.dask as simpeg
from SimPEG import maps, utils, data, optimization, maps, regularization, inverse_problem, directives, inversion, data_misfit
import discretize
from discretize.utils import mkvc, refine_tree_xyz
import SimPEG.electromagnetics.frequency_domain as fdem
import numpy as np
from scipy.spatial import cKDTree
import matplotlib.pyplot as plt
from pymatsolver import Pardiso as Solver

# %% [markdown]
# ## Loading the simulation
#
# Load the *.msh file and *.mod file which are UBC formatted. We can extract the active cells by searching for the value used to indicate air cells on line 10 of the following cell
#
# A histogram of the model is generated to get an idea of how many units are present

# %%
# let import the mesh in UBC format
mesh_file = r"C:\Users\johnk\Documents\git\jresearch\PGI\tdem\octree_mesh\output_files\octree_mesh.txt"
mesh = discretize.TreeMesh.read_UBC(mesh_file)

# load the conductivity model
conductivity_file = r"C:\Users\johnk\Documents\git\jresearch\PGI\tdem\octree_model\octree_model.con"
model = discretize.TreeMesh.read_model_UBC(mesh, conductivity_file)

# extract the acive files
active = model > 1e-8

# model[model == -1] = 50

print(model.shape, mesh.nC, active.sum())

plt.hist(1 / model[active], 100)
plt.show()

print(model[active].min(), model[active].max())
# Out:
# (77988,) 77988 60820
# 0.001 0.1

# %% [markdown]
# ## Load the receiver stations array
#
# Simply load in a CSV file with utm easting, northing and elevation.

# %%
# create receivers
rx_x, rx_y = np.meshgrid(np.arange(0, 1000, 100), np.arange(0, 1000, 100))
receivers = np.hstack((mkvc(rx_x, 2), mkvc(rx_y, 2), np.ones((np.prod(rx_x.shape), 1))*50.0))
print(f"receiver numbers: {receivers.shape}")

source_locations = np.array(
    [[-50, -200, 0],[300, -200, 0],[600, -200, 0],[950, -200, 0]]
)

plt.plot(receivers[:, 0], receivers[:, 1], '.')
plt.plot(source_locations[:, 0], source_locations[:, 1], '-g')
plt.show()

# # process the receivers
# receivers = np.genfromtxt(r"C:\Users\johnk\Documents\git\jresearch\PGI\mt\simulation_inputs\stations.csv", delimiter=',', skip_header=1)

# plt.plot(receivers[:, 0], receivers[:, 1], '.')
# plt.show()
plt_model = 1 / model
plt_model[~active] = np.nan

fig, ax = plt.subplots(1, 2, figsize=(18, 10))

collect_obj = mesh.plot_slice(plt_model, ax=ax[0], ind=int(505), grid=True, normal='Z', clim=[10, 1000], pcolor_opts={"cmap": 'Spectral_r'})
# color_bar = plt.colorbar(collect_obj[0])
ax[0].plot(source_locations[:, 0], source_locations[:, 1], '-g', linewidth=6)
ax[0].text(300, -250, 'Transmiter', fontsize=20, color='white', fontweight='bold')

ax[0].set_xlim([-100, 1000])
ax[0].set_ylim([-300, 1000])
ax[0].set_aspect('equal')
# ax[0].axis('equal')
collect_obj = mesh.plot_slice(plt_model, ax=ax[1], ind=int(515), grid=True, normal='Y', clim=[10, 1000], pcolor_opts={"cmap": 'Spectral_r'})
# color_bar = plt.colorbar(collect_obj[0])
ax[1].set_xlim([-100, 1000])
ax[1].set_ylim([-600, 100])
ax[1].set_aspect('equal')
fig.colorbar(collect_obj[0], label=r'resistivity ($\Omega$-m)')
plt.show()
# Out:
# receiver numbers: (100, 3)

# %% [markdown]
# ## Setting up the simulation
#
# Here the background is set to the median of the model provided. This may or may not need to be adjusted depedning on the experiment.
#
# The simpeg framework is now incorporated by defining the receiver type and components. This can be modified for impedance data or tipper. For tipper data replace the receiver simpeg object type with: `Point3DTipper(receivers, orientation=rx_orientation, component='real')` and `Point3DTipper(receivers, orientation=rx_orientation, component='imag')` on starting on line 12 and 17.
#
# The model slice is also generated to confirm simulated targets.

# %%
# set frequencies
freqs = ['10', '50', '200']
frequencies = freqs

background = 100 # np.median(model[active])
# create background conductivity model
sigBG = np.zeros(mesh.nC) + 1 / background
sigBG[~active] = 1e-8

source_list = []  # Create empty list to store sources

# Each unique location and frequency defines a new transmitter
for ii in range(len(frequencies)):

    # Define receivers of different type at each location
    bzr_receiver = fdem.receivers.PointMagneticFluxDensity(
        receivers, "z", "real"
    )
    bzi_receiver = fdem.receivers.PointMagneticFluxDensity(
        receivers, "z", "imag"
    )
    
    byr_receiver = fdem.receivers.PointMagneticFluxDensity(
        receivers, "y", "real"
    )
    byi_receiver = fdem.receivers.PointMagneticFluxDensity(
        receivers, "y", "imag"
    )
    
    bxr_receiver = fdem.receivers.PointMagneticFluxDensity(
        receivers, "x", "real"
    )
    bxi_receiver = fdem.receivers.PointMagneticFluxDensity(
        receivers, "x", "imag"
    )

    receivers_list = [bzr_receiver, bzi_receiver, byr_receiver, byi_receiver, bxr_receiver, bxi_receiver]

    # Must define the transmitter properties and associated receivers
    source_list.append(
        fdem.sources.LineCurrent(
            receiver_list=receivers_list,
            frequency=float(frequencies[ii]),
            location=source_locations
        )
    )

# Survey MT
survey = fdem.Survey(source_list)
# survey.drape_topography(mesh, active, option='top')                       # drape topo

# plot the mesh
model_plot = model.copy()
model_plot[~active] = np.nan
ind_slice = int(20)
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)
mesh.plotSlice(model_plot, normal="X", ax=ax, ind=ind_slice, grid=True)
ax.axis("equal")
# Out:
# c:\Users\johnk\Anaconda3\envs\jresearch\lib\site-packages\discretize\utils\code_utils.py:217: FutureWarning: TreeMesh.plotSlice has been deprecated, please use TreeMesh.plot_slice. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(
# (-14910.0, 15810.0, -12800.0, 12800.0)

# %% [markdown]
# ## Running the forward simulation
#
# Here simpeg map and simulation objects are created which are then used to calculate the forward data using the geological model imported in UBC format.

# %%
# Set the mapping
actMap = maps.InjectActiveCells(
    mesh=mesh, indActive=active, valInactive=np.log(1e-8)
)
mapping = maps.ExpMap(mesh) * actMap

# Setup the problem object
sim = fdem.simulation.Simulation3DMagneticFluxDensity(
        mesh,
        survey=survey,
        sigmaMap=mapping,
        solver=Solver
    )

sim.model = sigBG[active]

# -------------------------------------------------------------

# calculate the fields

#

import time
directory = '.'
# source_list = src_list
models = {

    "L_block": np.log(model[active]),
}

fields = {}

for key, sig in models.items():
    if key not in fields.keys(): 
        print(f"starting {key}")
        t = time.time()
        fields[key] = sim.fields(sig)
        # np.save(f"{directory}/fields_{key}_{freq}", f[:, f"{sim._solutionType}"])
        print(f"done {key}... elapsed time: {time.time()-t:1.1e}s \n")

sim.survey.dtrue = sim.dpred(np.log(model[active]), f=fields["L_block"])
# create observations
sim.survey.dobs = sim.survey.dtrue
# Out:
# starting L_block
# c:\Users\johnk\Anaconda3\envs\jresearch\lib\site-packages\discretize\utils\code_utils.py:182: FutureWarning: TreeMesh.edgeCurl has been deprecated, please use TreeMesh.edge_curl. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(message, Warning)
# c:\Users\johnk\Anaconda3\envs\jresearch\lib\site-packages\discretize\utils\code_utils.py:182: FutureWarning: TreeMesh.vectorNx has been deprecated, please use TreeMesh.nodes_x. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(message, Warning)
# c:\Users\johnk\Anaconda3\envs\jresearch\lib\site-packages\discretize\utils\code_utils.py:182: FutureWarning: TreeMesh.vectorNy has been deprecated, please use TreeMesh.nodes_y. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(message, Warning)
# c:\Users\johnk\Anaconda3\envs\jresearch\lib\site-packages\discretize\utils\code_utils.py:182: FutureWarning: TreeMesh.vectorNz has been deprecated, please use TreeMesh.nodes_z. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(message, Warning)
# done L_block... elapsed time: 4.1e+02s
# c:\Users\johnk\Anaconda3\envs\jresearch\lib\site-packages\discretize\utils\code_utils.py:217: FutureWarning: TreeMesh.getInterpolationMat has been deprecated, please use TreeMesh.get_interpolation_matrix. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(

# %% [markdown]
# ## Plotting the simulation data
#
# Line 11 and 20 will need to be adjusted accoringly depending on the data being observed.

# %%
print(survey.dobs)
# Assign uncertainties
std = 0.05  # 5% std
sim.survey.std = np.abs(survey.dobs) * std
# make data object
fwd_data = data.Data(sim.survey)

# reshape data for plotting
print(receivers.shape[0])
num_station = receivers.shape[0]

num_frequencies = len(freqs)

num_sets = int(survey.dobs.shape[0] / len(freqs))
dnew = np.reshape(survey.dobs, (num_frequencies, num_sets))
stdnew = np.reshape(survey.std, (num_frequencies, num_sets))

cnt = 0

profile_data = {

    '10':{

    'real': [],
    'imag': []

    },

    '50':{

    'real': [],
    'imag': []

    },

    '200':{

    'real': [],
    'imag': []

    }

}

for freq in freqs:
    cnt_comp = 0
    comps_ = ['bz_r', 'bz_i', 'by_r', 'by_i', 'bx_r', 'bx_i']
    fig1 = plt.figure(figsize=(18, 14))
    for rx_orientation in range(len(comps_)):
        pert = 1e-2
        pert_diag = np.percentile(np.abs(dnew[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)]), 10)
        if comps_[rx_orientation][-2:] == 'xx':
            stdnew[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)] = np.abs(dnew[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)] * 0.1) + pert
        elif comps_[rx_orientation][-2:] == 'yy':
            stdnew[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)] = np.abs(dnew[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)] * 0.1) + pert
        elif comps_[rx_orientation] == 'bz_r':
            # print(dnew[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)].shape)
            profile_data[freq]['real'].append(dnew[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)]) 
        elif comps_[rx_orientation] == 'bz_i':
            profile_data[freq]['imag'].append(dnew[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)]) 
        else:
#             print(pert_diag)
            stdnew[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)] = np.abs(dnew[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)] * 0.05) + pert_diag
            
        ax = plt.subplot(4,2, cnt_comp + 1)
        im = utils.plot_utils.plot2Ddata(receivers, dnew[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)], ax=ax, contourOpts={'cmap':'jet'})
        ax.set_title(comps_[rx_orientation])
        plt.colorbar(im[0])
        cnt_comp += 1
    cnt += 1
    fig1.suptitle(freq + ' Hz Forward Data', fontsize='20')
plt.show()
print(mkvc(stdnew)[:3], stdnew.flatten('F').shape)
# Out:
# [ 5.80583084e-10  3.68281003e-10  2.59529040e-10 ... -6.26984183e-12
#  -5.61859544e-12 -5.04514631e-12]
# 100
# [2.90291542e-11 2.90240132e-11 2.89938649e-11] (1800,)

# %% [markdown]
# ## Plotting figures

# %%
from matplotlib.colors import LogNorm, Normalize
# fields['halfspace'] = sim.fields(np.log(sigBG[active]))
# ---------------------------------------------------------------------------------------------------------------------------

# plot the profile subplots

#

data_dict = fwd_data

# print(fields, rx_list[:2])

# lets plot some plots
fig, ax = plt.subplots(3, 2, figsize=(10, 10))
idx = 8

for key in profile_data.keys():
    print(profile_data[key]['real'][0][(10*idx):(10*idx + 10)].shape, key, 10*idx)
    ax[1, 1].plot(np.arange(0, 1000, 100), profile_data[key]['real'][0][(10*idx):(10*idx + 10)], 'o-', label=f"{key} Hz")
    ax[2, 1].plot(np.arange(0, 1000, 100), profile_data[key]['imag'][0][(10*idx):(10*idx + 10)], 'o-', label=f"{key} Hz")

ax[1, 1].legend()
ax[1, 1].text(-0.1, 1.15, 'd)', transform=ax[1, 1].transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')
ax[1, 1].set_title('Line 800E Real')
ax[2, 1].set_title('Line 800E imag')
ax[2, 1].legend()
ax[2, 1].text(-0.1, 1.15, 'f)', transform=ax[2, 1].transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

# ---------------------------------------------------------------------------------------------------------------------------

# plot the plan-map subplots

#

key = "10"
im = utils.plot_utils.plot2Ddata(receivers, profile_data[key]['real'][0], ax=ax[1, 0], contourOpts={'cmap':'Spectral'})
ax[1, 0].set_title(f"{key} Hz {comps_[0]}")
plt.colorbar(im[0])

ax[1, 0].text(-0.1, 1.15, 'c)', transform=ax[1, 0].transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

im = utils.plot_utils.plot2Ddata(receivers, profile_data[key]['imag'][0], ax=ax[2, 0], contourOpts={'cmap':'Spectral'})
ax[2, 0].set_title(f"{key} Hz {comps_[1]}")
plt.colorbar(im[0])

ax[2, 0].text(-0.1, 1.15, 'e)', transform=ax[2, 0].transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

# ---------------------------------------------------------------------------------------------------------------------------

# plot the slice of currents and B-field subplots

#

ax[0, 0].text(-0.1, 1.15, 'a)', transform=ax[0, 0].transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

ax[0, 1].text(-0.1, 1.15, 'b)', transform=ax[0, 1].transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')

frequencies = [10, 50, 200]

xlim = np.r_[1000, 7000]
ylim = np.r_[-1500, 200]

key = "L_block"
src_ind = 0

out = mesh.plot_slice(
    fields[key][source_list[src_ind], "j"][:, 0].imag, "E", view="vec", normal="Y", ax=ax[0, 0],
    pcolor_opts={"cmap": 'magma'},
    stream_threshold=10,
)
plt.colorbar(out[1], ax=ax[0, 0], shrink=0.5)
ax[0, 0].set_xlim(xlim)
ax[0, 0].set_ylim(ylim)
ax[0, 0].set_title(f"J imag, {frequencies[src_ind]} Hz, XZ-slice")
ax[0, 0].set_aspect(1)


key = "L_block"
src_ind = 0
subtract = "halfspace" 

plotme = fields[key][source_list[src_ind], "b"][:, 0].real
if subtract is not None:
    plotme = plotme - fields[subtract][source_list[src_ind], "b"][:, 0].real

out = mesh.plot_slice(
    plotme, "F", view="vec", normal="X", ax=ax[0, 1],
    range_x=xlim, range_y=ylim, pcolor_opts={"cmap": 'magma'}, #LogNorm(vmin=3e-11, vmax=1e-7)},
    stream_threshold=10,
    cmap='jet'
)
plt.colorbar(out[1], ax=ax[0, 1], shrink=0.5, pad=0.1)
ax[0, 1].set_xlim(xlim)
ax[0, 1].set_ylim(ylim)
ax[0, 1].set_title(f"Anomalous B real, {frequencies[src_ind]} Hz, YZ slice")
ax[0, 1].set_aspect(1)

plt.show()
# ax[2].set_xlabel("x (m)")
print(receivers[10*idx, :])
# Out:
# (10,) 10 80
# (10,) 50 80
# (10,) 200 80
# [800.   0.  50.]

# %%
# save the data
directory = '.'
# key = 'L_block'
for key in fields.keys():

    for ii in range(3):

        freq = frequencies[ii]

        np.save(f"{directory}/fields_{key}_{freq}", fields[key][source_list[ii], :]['bSolution'])

print("saved")
# Out:
# saved

# %%
# np.save('Lb-imp_all-obs.npy', survey.dobs)
# np.save('Lb-imp-all-dpred_pre.npy', invProb.dpred)
# plt.plot(mkvc(stdnew), '.r')
# plt.plot(survey.std, '.', ms=1)
# plt.show()
# np.save('csem_fields.npy', sim.fields(np.log(model[active])))

## Fill the data object
fwd_data.dobs = sim.survey.dobs
fwd_data.standard_deviation = stdnew.flatten()  # sim.survey.std
sim.survey.std = stdnew.flatten()
survey.std = stdnew.flatten()

plt.plot(survey.dobs, '.r')
plt.plot(survey.std, '.', ms=1)
plt.show()

# %%
Wd = 1 / survey.std
plt.hist(Wd, 100)
plt.show()
# Setup the inversion proceedure
# Define a counter
C = utils.Counter()
# Optimization
opt = optimization.ProjectedGNCG(maxIter=10, upper=np.inf, lower=-np.inf)
opt.counter = C
opt.maxIterCG = 20
# opt.LSshorten = 0.5
opt.remember('xc')
# Data misfit
dmis = data_misfit.L2DataMisfit(data=fwd_data, simulation=sim)
dmis.W = Wd
# Regularization
regmap = maps.IdentityMap(nP=int(active.sum()))
# reg = regularization.Sparse(mesh, indActive=active, mapping=regmap)
reg = regularization.Simple(mesh, indActive=active, mapping=regmap)

reg.alpha_s = 4e-6
reg.alpha_x = 1.
reg.alpha_y = 1.
reg.alpha_z = 1.
# reg.mrefInSmooth = True
# Inversion problem
invProb = inverse_problem.BaseInvProblem(dmis, reg, opt)
invProb.counter = C
# Beta schedule
beta = directives.BetaSchedule()
beta.coolingRate = 1.
beta.coolingFactor = 2.
# Initial estimate of beta
beta_est = directives.BetaEstimate_ByEig(beta0_ratio=1e0)
# Target misfit stop
targmis = directives.TargetMisfit()
# targmis.target = survey.nD
saveIter = directives.SaveModelEveryIteration()
# Create an inversion object
directive_list = [beta, beta_est, targmis, saveIter]
inv = inversion.BaseInversion(invProb, directiveList=directive_list)

# Set the conductivity values
sig_half = 0.01
sig_air = 1e-8
# Make the background model
sigma_0 = np.ones(mesh.nC) * sig_air
sigma_0[active] = sig_half
m_0 = np.log(sigma_0[active])

import time
start = time.time()
# Run the inversion
mopt = inv.run(m_0)
print('Inversion took {0} seconds'.format(time.time() - start))
# Out:
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# c:\Users\johnk\Anaconda3\envs\jresearch\lib\site-packages\discretize\utils\code_utils.py:182: FutureWarning: TreeMesh._cellGradxStencil has been deprecated, please use TreeMesh.stencil_cell_gradient_x. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(message, Warning)
# c:\Users\johnk\Anaconda3\envs\jresearch\lib\site-packages\discretize\utils\code_utils.py:182: FutureWarning: TreeMesh._cellGradyStencil has been deprecated, please use TreeMesh.stencil_cell_gradient_y. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(message, Warning)
# c:\Users\johnk\Anaconda3\envs\jresearch\lib\site-packages\discretize\utils\code_utils.py:182: FutureWarning: TreeMesh._cellGradzStencil has been deprecated, please use TreeMesh.stencil_cell_gradient_z. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(message, Warning)
# SimPEG.SaveModelEveryIteration will save your models as: '.\###-InversionModel-2023-04-07-17-43.npy'
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  3.22e-06  1.23e+05  0.00e+00  1.23e+05    3.83e+03      0
#    1  1.61e-06  1.03e+04  1.22e+07  1.03e+04    5.11e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.2305e+04
# 0 : |xc-x_last| = 1.7893e+02 <= tolX*(1+|x0|) = 1.1367e+02
# 0 : |proj(x-g)-x|    = 5.1078e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.1078e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# Inversion took 2692.113307952881 seconds

# %%
print(invProb.beta, invProb.phi_d, invProb.phi_m, sim.survey.nD)
# map the conductivity
cond_est = mapping * mopt

discretize.TreeMesh.writeUBC(mesh,'Lb-bfield_simple-octree-v2.msh', models={'Lb-bfield_simple-octree-v2.con': cond_est})
# Out:
# 8.03966765090864e-07 845.2533178972919 19114852.788832083 1800
# c:\Users\johnk\Anaconda3\envs\jresearch\lib\site-packages\discretize\utils\code_utils.py:217: FutureWarning: TreeMesh.writeUBC has been deprecated, please use TreeMesh.write_UBC. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(

# %%
# modeli = np.ones(mesh.nC) 
modeli = 1 / cond_est
modeli[~active] = np.nan
# modeli[active] = cond_est
plt.figure(figsize=(24, 24))
plt.suptitle('Model')
ax = plt.subplot(2, 2, 1)
collect_obj = mesh.plot_slice(modeli, ax=ax, ind=int(65), grid=True, normal='Y', clim=[1, 100], cmap='jet')
color_bar = plt.colorbar(collect_obj[0])
ax.axis('equal')
ax1 = plt.subplot(2, 2, 2)
collect_obj1 = mesh.plot_slice(modeli, ax=ax1, ind=int(70), grid=True, normal='X', clim=[1, 100])
# color_bar1 = plt.colorbar()
ax1.axis('equal')
# plt.show()

ax2 = plt.subplot(2, 2, 3)
collect_obj2 = mesh.plot_slice(modeli, ax=ax2, ind=int(120), grid=True, normal='Z', clim=[1, 100])
# color_bar2 = plt.colorbar()
ax2.set_xlim([-1000, 7000])
ax2.set_ylim([-1000, 7000])
# ax2.axis('equal')
# plt.show()

ax3 = plt.subplot(2, 2, 4)
collect_obj3 = mesh.plot_slice(modeli, ax=ax3, ind=int(100), grid=True, normal='Z', clim=[1, 100])
# color_bar3 = plt.colorbar()
ax3.set_xlim([-5000, 30000])
ax3.axis('equal')
plt.show()

# print(mesh.nCz)

# %%
# plot dpred & dobs for specific station - checking fit of each frequency for a station
num_sets = int(survey.dobs.shape[0] / 3.)
dnew = np.reshape(survey.dobs, (3, num_sets))
dpred_new = np.reshape(invProb.dpred, (3, num_sets))
d_wd = dmis.W.diagonal()
Wd_new = np.reshape(d_wd, (3, num_sets))
# set station ID
stn_id = 50
location_id = receivers[stn_id, :]
plt.figure(figsize=(16, 12))
plt.suptitle('Station: x= {0}, y = {1}'.format(location_id[0], location_id[1]))
cnt = 0
for rx_orientation in comps_:
    ax = plt.subplot(4,2, cnt + 1)
    ax.semilogx(survey.frequencies, dnew[:, stn_id + int(cnt * num_station)], '.k')
    ax.semilogx(survey.frequencies, dpred_new[:, stn_id + int(cnt * num_station)], '.r')
    ax.set_title(rx_orientation)
    ax.legend(['dobs', 'dpred'])
    ax.set_xlabel('frequency (Hz)')
    cnt += 1

plt.show()

# set second station ID
stn_id = 64
location_id = receivers[stn_id, :]
plt.figure(figsize=(16, 12))
plt.suptitle('Station: x= {0}, y = {1}'.format(location_id[0], location_id[1]))
cnt = 0
for rx_orientation in comps_:
    ax = plt.subplot(4,2, cnt + 1)
    ax.semilogx(survey.frequencies, dnew[:, stn_id + int(cnt * num_station)], '.k')
    ax.semilogx(survey.frequencies, dpred_new[:, stn_id + int(cnt * num_station)], '.r')
    ax.set_title(rx_orientation)
    ax.legend(['dobs', 'dpred'])
    ax.set_xlabel('frequency (Hz)')
    cnt += 1

plt.show()

# %%
# plotting obs maps
freqs = ['10', '50', '200']
cnt = 0
cnt_comp = 0
comps_ = ['xx_r', 'xx_p', 'xy_r', 'xy_p', 'yx_r', 'yx_p', 'yy_r', 'yy_p']
fig1 = plt.figure(figsize=(18, 14))
for rx_orientation in range(len(comps_)):
    ax = plt.subplot(4,2, cnt_comp + 1)
    im = utils.plot_utils.plot2Ddata(rx_loc, dnew[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)], ax=ax)
    ax.set_title(comps_[rx_orientation])
    plt.colorbar(im[0])
    cnt_comp += 1
fig1.suptitle(freqs[cnt] + ' Hz', fontsize='20')
plt.show()

# plotting dpred maps
fig2 = plt.figure(figsize=(18, 14))
cnt_comp = 0
for rx_orientation in range(len(comps_)):
    ax = plt.subplot(4,2, cnt_comp + 1)
    im = utils.plot_utils.plot2Ddata(rx_loc, dpred_new[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)], ax=ax)
    ax.set_title(comps_[rx_orientation])
    plt.colorbar(im[0])
    cnt_comp += 1
fig2.suptitle(freqs[cnt] + ' Hz', fontsize='20')
plt.show()

# %%
# plotting residual maps
freqs = ['10', '50', '200']
comps_ = ['xx_r', 'xx_p', 'xy_r', 'xy_p', 'yx_r', 'yx_p', 'yy_r', 'yy_p']

cnt = 0
for freq in freqs:
    cnt_comp = 0
    fig1 = plt.figure(figsize=(18, 14))
    for rx_orientation in range(len(comps_)):
        ax = plt.subplot(4,2, cnt_comp + 1)
        residual = (dnew[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)] -
                    dpred_new[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)]) / Wd_new[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)]
        im = utils.plot_utils.plot2Ddata(rx_loc, residual, ax=ax)
        ax.set_title(comps_[rx_orientation])
        plt.colorbar(im[0])
        cnt_comp += 1
    cnt += 1
    fig1.suptitle(freq + ' Hz', fontsize='20')
plt.show()

# %%
# plotting residual histograms
comps_ = ['xx_r', 'xx_p', 'xy_r', 'xy_p', 'yx_r', 'yx_p', 'yy_r', 'yy_p']
cnt = 0
for freq in freqs:
    cnt_comp = 0
    fig = plt.figure(figsize=(18, 14))
    for rx_orientation in range(len(comps_)):
        ax = plt.subplot(4,2, cnt_comp + 1)
        residual = (dnew[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)] -
                    dpred_new[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)]) / Wd_new[cnt, num_station*rx_orientation:num_station*(rx_orientation + 1)]
        ax.hist(residual, 20)
        ax.set_title(comps_[rx_orientation])
        cnt_comp += 1
    cnt += 1
    fig.suptitle(freq + ' Hz', fontsize='20')
plt.show()

# %%
np.save('Lb-imp_all-octree-obs-v2.npy', survey.dobs)
np.save('Lb-imp_all-octree-dpred-v2.npy', invProb.dpred)
np.save('Lb-imp_all-octree-dmis-v2.npy', d_wd)
print(5000 / 60)
